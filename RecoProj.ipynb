# %% [markdown]
# ## BPD
#
# Bayesian Personalized Denoising
#
# ## Exemple
#
# One-Shot Learning (genre reco de la tronche de quelqu'un basée sur une seule image)
# On veut apprendre distance entre ```S(I_1, S(I_2))``` (I_1 et I_2 sont des images)
#
# On passe chaque image dans un RNN (tensur de dimension 3 pour RGB)
#
# pas bonne métrique accuracy quand classification de deux classes : une avec 90% l'autre avec 10
# oscar.defelice@gmail.com
#
# https://www.v7labs.com/blog/triplet-loss
# https://medium.com/wicds/face-recognition-using-siamese-networks-84d6f2e54ea4
